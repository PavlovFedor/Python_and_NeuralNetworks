# %% [markdown]
# # Подбор параметров для вычисления логических функций средствами однослойных искусственных нейронных сетей

# %% [markdown]
# В качестве примера построим и обучим искусственную нейронную сеть (ИНС) вычислению конъюнкции.
#
# Сначала подгрузим библиотеки с линейной моделью слоев Sequential, со слоями Dense

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

# %% [markdown]
# Создадим модель ИНС и добавим в нее один слой с одним нейроном (units = 1) и двумя входами (input_dim = 2)

# %%
from keras import activations
model = Sequential()
model.add(Dense(units = 1, input_dim = 2, activation='sigmoid'))

# %% [markdown]
# Скомпилируем, получившуюся ИНС

# %%
model.compile(optimizer='sgd', loss='mse', metrics=['binary_accuracy'])

# %% [markdown]
# Создадим обучающий набор X и вектор значений целевой функции (конъюнкции)

# %%
import numpy as np
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
X
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
y = np.array([0, 0, 0, 1])
y
# Out:
# array([0, 0, 0, 1])

# %% [markdown]
# Обучим ИНС

# %%
model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 557ms/step - loss: 0.2758 - binary_accuracy: 0.5000
# Epoch 2/5
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2757 - binary_accuracy: 0.5000
# Epoch 3/5
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2756 - binary_accuracy: 0.5000
# Epoch 4/5
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2755 - binary_accuracy: 0.5000
# Epoch 5/5
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2754 - binary_accuracy: 0.5000

# %% [markdown]
# Протестируем ИНС

# %%
model.predict(X)
# Out:
# array([[0.4988046 ],
#        [0.70385486],
#        [0.26753503],
#        [0.46588784]], dtype=float32)

# %% [markdown]
# Посмотрим как влияет выбор функции активации на результат классификации

# %%
f_act = ['elu', 'softmax', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'exponential', 'linear']
for f in f_act:
  model = Sequential()
  model.add(Dense(units = 1, input_dim = 2, activation=f))
  model.compile(optimizer='sgd', loss='mse', metrics=['binary_accuracy'])
  model.fit(X, y, epochs=10)
  yp = model.predict(X)
  print(f, yp)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 334ms/step - loss: 0.5772 - binary_accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5731 - binary_accuracy: 0.5000
# Epoch 3/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5690 - binary_accuracy: 0.5000
# Epoch 4/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5649 - binary_accuracy: 0.5000
# Epoch 5/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5608 - binary_accuracy: 0.5000
# Epoch 6/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5567 - binary_accuracy: 0.5000
# Epoch 7/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5527 - binary_accuracy: 0.5000
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5486 - binary_accuracy: 0.5000
# Epoch 9/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5446 - binary_accuracy: 0.5000
# Epoch 10/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5407 - binary_accuracy: 0.5000
# elu [[ 0.01511067]
#  [-0.58668303]
#  [ 0.93325037]
#  [ 0.03459918]]
# Epoch 1/10
# 1/1 [==============================] - 1s 684ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 2/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 3/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 4/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 5/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 6/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 7/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 8/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 9/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# Epoch 10/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7500 - binary_accuracy: 0.2500
# softmax [[1.]
#  [1.]
#  [1.]
#  [1.]]
# Epoch 1/10
# 1/1 [==============================] - 0s 335ms/step - loss: 1.7322 - binary_accuracy: 0.7500
# Epoch 2/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7137 - binary_accuracy: 0.7500
# Epoch 3/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6952 - binary_accuracy: 0.7500
# Epoch 4/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6769 - binary_accuracy: 0.7500
# Epoch 5/10
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6586 - binary_accuracy: 0.7500
# Epoch 6/10
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6401 - binary_accuracy: 0.7500
# Epoch 7/10
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6214 - binary_accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6023 - binary_accuracy: 0.7500
# Epoch 9/10
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5829 - binary_accuracy: 0.7500
# Epoch 10/10
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5632 - binary_accuracy: 0.7500
# selu [[ 0.09152772]
#  [ 0.10236104]
#  [-1.185206  ]
#  [-1.1792687 ]]
# Epoch 1/10
# 1/1 [==============================] - 0s 331ms/step - loss: 0.3973 - binary_accuracy: 0.2500
# Epoch 2/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3961 - binary_accuracy: 0.2500
# Epoch 3/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3948 - binary_accuracy: 0.2500
# Epoch 4/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3936 - binary_accuracy: 0.2500
# Epoch 5/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3924 - binary_accuracy: 0.2500
# Epoch 6/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3913 - binary_accuracy: 0.2500
# Epoch 7/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3901 - binary_accuracy: 0.2500
# Epoch 8/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3889 - binary_accuracy: 0.2500
# Epoch 9/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3878 - binary_accuracy: 0.2500
# Epoch 10/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3867 - binary_accuracy: 0.2500
# softplus [[0.6772488]
#  [0.7529166]
#  [0.3095612]
#  [0.3512168]]
# Epoch 1/10
# 1/1 [==============================] - 0s 331ms/step - loss: 0.2818 - binary_accuracy: 0.7500
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2743 - binary_accuracy: 0.7500
# Epoch 3/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2672 - binary_accuracy: 0.7500
# Epoch 4/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2606 - binary_accuracy: 0.7500
# Epoch 5/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2546 - binary_accuracy: 0.7500
# Epoch 6/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2491 - binary_accuracy: 0.7500
# Epoch 7/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2440 - binary_accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2393 - binary_accuracy: 0.7500
# Epoch 9/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2349 - binary_accuracy: 0.7500
# Epoch 10/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2308 - binary_accuracy: 0.7500
# softsign [[ 0.04001229]
#  [-0.17716826]
#  [ 0.2724398 ]
#  [ 0.10511451]]
# Epoch 1/10
# 1/1 [==============================] - 0s 324ms/step - loss: 0.7775 - binary_accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7341 - binary_accuracy: 0.5000
# Epoch 3/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6932 - binary_accuracy: 0.5000
# Epoch 4/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6547 - binary_accuracy: 0.5000
# Epoch 5/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6184 - binary_accuracy: 0.5000
# Epoch 6/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5841 - binary_accuracy: 0.5000
# Epoch 7/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5519 - binary_accuracy: 0.5000
# Epoch 8/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5214 - binary_accuracy: 0.5000
# Epoch 9/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4927 - binary_accuracy: 0.5000
# Epoch 10/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4657 - binary_accuracy: 0.5000
# relu [[0.        ]
#  [0.85964894]
#  [0.71774215]
#  [1.7118204 ]]
# Epoch 1/10
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1680 - binary_accuracy: 0.7500
# Epoch 2/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1665 - binary_accuracy: 0.7500
# Epoch 3/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1650 - binary_accuracy: 0.7500
# Epoch 4/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1635 - binary_accuracy: 0.7500
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1621 - binary_accuracy: 0.7500
# Epoch 6/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1607 - binary_accuracy: 0.7500
# Epoch 7/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1592 - binary_accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1578 - binary_accuracy: 0.7500
# Epoch 9/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1565 - binary_accuracy: 0.7500
# Epoch 10/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1551 - binary_accuracy: 0.7500
# tanh [[-0.0312667 ]
#  [ 0.682329  ]
#  [ 0.35218728]
#  [ 0.8433533 ]]
# Epoch 1/10
# 1/1 [==============================] - 0s 322ms/step - loss: 0.2626 - binary_accuracy: 0.7500
# Epoch 2/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2625 - binary_accuracy: 0.7500
# Epoch 3/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2624 - binary_accuracy: 0.7500
# Epoch 4/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2623 - binary_accuracy: 0.7500
# Epoch 5/10
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2623 - binary_accuracy: 0.7500
# Epoch 6/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2622 - binary_accuracy: 0.7500
# Epoch 7/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2621 - binary_accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2620 - binary_accuracy: 0.7500
# Epoch 9/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2619 - binary_accuracy: 0.7500
# Epoch 10/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2618 - binary_accuracy: 0.7500
# sigmoid [[0.49781963]
#  [0.47484362]
#  [0.34780115]
#  [0.3272372 ]]
# Epoch 1/10
# 1/1 [==============================] - 0s 367ms/step - loss: 0.2877 - binary_accuracy: 0.7500
# Epoch 2/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2877 - binary_accuracy: 0.7500
# Epoch 3/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2876 - binary_accuracy: 0.7500
# Epoch 4/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2875 - binary_accuracy: 0.7500
# Epoch 5/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2875 - binary_accuracy: 0.7500
# Epoch 6/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2874 - binary_accuracy: 0.7500
# Epoch 7/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2874 - binary_accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2873 - binary_accuracy: 0.7500
# Epoch 9/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2872 - binary_accuracy: 0.7500
# Epoch 10/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2872 - binary_accuracy: 0.7500
# hard_sigmoid [[0.49926665]
#  [0.33047888]
#  [0.35309368]
#  [0.18430594]]
# Epoch 1/10
# 1/1 [==============================] - 0s 337ms/step - loss: 0.7796 - binary_accuracy: 0.2500
# Epoch 2/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7491 - binary_accuracy: 0.2500
# Epoch 3/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7215 - binary_accuracy: 0.2500
# Epoch 4/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6966 - binary_accuracy: 0.2500
# Epoch 5/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6739 - binary_accuracy: 0.2500
# Epoch 6/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6531 - binary_accuracy: 0.2500
# Epoch 7/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6340 - binary_accuracy: 0.2500
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6164 - binary_accuracy: 0.2500
# Epoch 9/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6002 - binary_accuracy: 0.2500
# Epoch 10/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5851 - binary_accuracy: 0.2500
# exponential [[0.87673444]
#  [0.817456  ]
#  [0.90773255]
#  [0.84635824]]
# Epoch 1/10
# 1/1 [==============================] - 0s 315ms/step - loss: 0.6662 - binary_accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6319 - binary_accuracy: 0.5000
# Epoch 3/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5998 - binary_accuracy: 0.5000
# Epoch 4/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5697 - binary_accuracy: 0.5000
# Epoch 5/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5414 - binary_accuracy: 0.5000
# Epoch 6/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5149 - binary_accuracy: 0.5000
# Epoch 7/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4900 - binary_accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4666 - binary_accuracy: 0.7500
# Epoch 9/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4447 - binary_accuracy: 0.7500
# Epoch 10/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4241 - binary_accuracy: 0.7500
# linear [[-0.11690535]
#  [ 1.0433564 ]
#  [ 0.42177048]
#  [ 1.5820323 ]]

# %% [markdown]
# 1. Проверьте влияние на результат еще и таких параметров, как optimizer, loss, metrics

# %% [markdown]
# 2. Скомбинируйте изменение нескольких параметров: activation, optimizer, loss, metrics, -- для проверки их комплексного влияния на результат
